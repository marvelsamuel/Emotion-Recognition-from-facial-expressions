# %% [markdown]
# # 1. Import Libraries

# %%
import os
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sn
from collections import Counter
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras import regularizers

import keras.backend as K
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping

from IPython.display import Image, HTML
from tensorflow.keras.utils import plot_model

# %% [markdown]
# # 2. Parameter

# %%
# declare path
train_dir = '../input/fer2013/train/'
test_dir = '../input/fer2013/test/'

# Image size

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

BS = 64
EPOCHS = 100
ADAM_LEARNING_RATE = 0.0001
PATIENCE =10

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %% [markdown]
# # 3. Prepare data

# %%
# Data augmentation

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   featurewise_center=False,
                                   featurewise_std_normalization=False,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
# Load datasat

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # 4. Explore data

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')

HTML(train_count.append(test_count).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>surprise</th>
#       <th>fear</th>
#       <th>angry</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>disgust</th>
#       <th>happy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3171</td>
#       <td>4097</td>
#       <td>3995</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>436</td>
#       <td>7215</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>831</td>
#       <td>1024</td>
#       <td>958</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>111</td>
#       <td>1774</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Data labels

class_labels = test_dataset.class_indices
class_labels
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
# See the shape of any data

train_sample=next(train_dataset)
print(train_sample[0].shape)
# Out:
# (64, 48, 48, 3)

# %%
# # lot distribution of train/test dataste per class

x = list(test_count.columns)
y1 =train_count.iloc[0].to_list()
y2 = test_count.iloc[0].to_list()
plt.figure(figsize=(12,7))

plt.bar(x, y1, color='blue')
plt.bar(x, y2, bottom=y1, color='violet')
plt.xlabel("Emotions")
plt.ylabel("Train & Test data")
plt.legend(["Train", "Test"], loc='upper left')
plt.title("FER-2013")
plt.savefig('distribution.png')
plt.show()

# %%
# Plot image of each class

plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    img = load_img((train_dir + expression +'/'+ os.listdir(train_dir + expression)[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# # 5. Model

# %%
# VGG16

base_model = tf.keras.applications.VGG16(input_shape= IMAGE_SHAPE,include_top=False,weights="imagenet")
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 3s 0us/step
# 58900480/58889256 [==============================] - 3s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 48, 48, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 48, 48, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 48, 48, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 24, 24, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 24, 24, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 24, 24, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 12, 12, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 12, 12, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 12, 12, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 12, 12, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 6, 6, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 6, 6, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Freezing Layers

for layer in base_model.layers[:11]:
    layer.trainable=False

# %%
# Build transfer learning Model

model=Sequential()
model.add(base_model)
model.add(BatchNormalization())
model.add(GaussianNoise(0.01))
model.add(GlobalAveragePooling2D())

model.add(Flatten())
model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(7, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 1, 1, 512)         14714688
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, 1, 512)         2048
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 1, 1, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 14,883,399
# Trainable params: 13,146,119
# Non-trainable params: 1,737,280
# _________________________________________________________________

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)

# %%
# Run Model

counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
mcp = ModelCheckpoint('model.h5')
es = EarlyStopping(verbose=1, patience=20)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks = [lrd,mcp,es], 
                  class_weight = class_weights)
# Out:
# Epoch 1/100
# 449/449 [==============================] - 215s 458ms/step - loss: 5.2506 - accuracy: 0.8151 - precision: 0.2202 - recall: 0.1159 - auc: 0.5648 - f1_score: 0.1515 - val_loss: 10.3250 - val_accuracy: 0.7876 - val_precision: 0.2567 - val_recall: 0.2566 - val_auc: 0.5809 - val_f1_score: 0.2562
# Epoch 2/100
# 449/449 [==============================] - 57s 128ms/step - loss: 4.5566 - accuracy: 0.8312 - precision: 0.3079 - recall: 0.1456 - auc: 0.6264 - f1_score: 0.1973 - val_loss: 3.5952 - val_accuracy: 0.7848 - val_precision: 0.1743 - val_recall: 0.1356 - val_auc: 0.5782 - val_f1_score: 0.1538
# Epoch 3/100
# 449/449 [==============================] - 57s 128ms/step - loss: 4.0873 - accuracy: 0.8421 - precision: 0.3845 - recall: 0.1754 - auc: 0.6767 - f1_score: 0.2405 - val_loss: 2.8098 - val_accuracy: 0.8285 - val_precision: 0.3810 - val_recall: 0.3207 - val_auc: 0.6977 - val_f1_score: 0.3476
# Epoch 4/100
# 449/449 [==============================] - 58s 129ms/step - loss: 3.7670 - accuracy: 0.8528 - precision: 0.4637 - recall: 0.1944 - auc: 0.7100 - f1_score: 0.2732 - val_loss: 3.1938 - val_accuracy: 0.8195 - val_precision: 0.2197 - val_recall: 0.1032 - val_auc: 0.5781 - val_f1_score: 0.1399
# Epoch 5/100
# 449/449 [==============================] - 56s 125ms/step - loss: 3.4756 - accuracy: 0.8599 - precision: 0.5242 - recall: 0.2081 - auc: 0.7412 - f1_score: 0.2972 - val_loss: 3.0126 - val_accuracy: 0.8172 - val_precision: 0.2284 - val_recall: 0.1174 - val_auc: 0.5948 - val_f1_score: 0.1561
# Epoch 6/100
# 449/449 [==============================] - 57s 126ms/step - loss: 3.2398 - accuracy: 0.8669 - precision: 0.5872 - recall: 0.2300 - auc: 0.7684 - f1_score: 0.3299 - val_loss: 1.9884 - val_accuracy: 0.8708 - val_precision: 0.6028 - val_recall: 0.2799 - val_auc: 0.7942 - val_f1_score: 0.3819
# Epoch 7/100
# 449/449 [==============================] - 56s 125ms/step - loss: 3.1163 - accuracy: 0.8689 - precision: 0.6046 - recall: 0.2378 - auc: 0.7846 - f1_score: 0.3406 - val_loss: 1.8563 - val_accuracy: 0.8741 - val_precision: 0.6780 - val_recall: 0.2258 - val_auc: 0.8152 - val_f1_score: 0.3365
# Epoch 8/100
# 449/449 [==============================] - 57s 127ms/step - loss: 2.9779 - accuracy: 0.8725 - precision: 0.6329 - recall: 0.2565 - auc: 0.8027 - f1_score: 0.3645 - val_loss: 1.8994 - val_accuracy: 0.8764 - val_precision: 0.7312 - val_recall: 0.2137 - val_auc: 0.7989 - val_f1_score: 0.3271
# Epoch 9/100
# 449/449 [==============================] - 57s 126ms/step - loss: 2.8584 - accuracy: 0.8751 - precision: 0.6498 - recall: 0.2727 - auc: 0.8183 - f1_score: 0.3834 - val_loss: 2.0180 - val_accuracy: 0.8715 - val_precision: 0.6291 - val_recall: 0.2455 - val_auc: 0.7741 - val_f1_score: 0.3523
# Epoch 10/100
# 449/449 [==============================] - 55s 123ms/step - loss: 2.7916 - accuracy: 0.8756 - precision: 0.6481 - recall: 0.2827 - auc: 0.8236 - f1_score: 0.3928 - val_loss: 1.9342 - val_accuracy: 0.8601 - val_precision: 0.5178 - val_recall: 0.3031 - val_auc: 0.8000 - val_f1_score: 0.3810
# Epoch 11/100
# 449/449 [==============================] - 57s 127ms/step - loss: 2.6718 - accuracy: 0.8796 - precision: 0.6751 - recall: 0.3035 - auc: 0.8390 - f1_score: 0.4179 - val_loss: 1.6516 - val_accuracy: 0.8823 - val_precision: 0.7295 - val_recall: 0.2795 - val_auc: 0.8528 - val_f1_score: 0.4031
# Epoch 12/100
# 449/449 [==============================] - 55s 122ms/step - loss: 2.5970 - accuracy: 0.8815 - precision: 0.6802 - recall: 0.3215 - auc: 0.8474 - f1_score: 0.4357 - val_loss: 1.5719 - val_accuracy: 0.8861 - val_precision: 0.7528 - val_recall: 0.3020 - val_auc: 0.8659 - val_f1_score: 0.4306
# Epoch 13/100
# 449/449 [==============================] - 55s 123ms/step - loss: 2.5022 - accuracy: 0.8832 - precision: 0.6860 - recall: 0.3367 - auc: 0.8575 - f1_score: 0.4507 - val_loss: 1.5739 - val_accuracy: 0.8860 - val_precision: 0.7398 - val_recall: 0.3118 - val_auc: 0.8630 - val_f1_score: 0.4382
# Epoch 14/100
# 449/449 [==============================] - 55s 123ms/step - loss: 2.4253 - accuracy: 0.8859 - precision: 0.6996 - recall: 0.3525 - auc: 0.8640 - f1_score: 0.4678 - val_loss: 1.6867 - val_accuracy: 0.8782 - val_precision: 0.6497 - val_recall: 0.3204 - val_auc: 0.8356 - val_f1_score: 0.4267
# Epoch 15/100
# 449/449 [==============================] - 55s 122ms/step - loss: 2.3525 - accuracy: 0.8877 - precision: 0.7039 - recall: 0.3686 - auc: 0.8703 - f1_score: 0.4831 - val_loss: 1.6575 - val_accuracy: 0.8795 - val_precision: 0.6467 - val_recall: 0.3451 - val_auc: 0.8418 - val_f1_score: 0.4492
# Epoch 16/100
# 449/449 [==============================] - 55s 122ms/step - loss: 2.3002 - accuracy: 0.8896 - precision: 0.7146 - recall: 0.3786 - auc: 0.8758 - f1_score: 0.4941 - val_loss: 1.4133 - val_accuracy: 0.8938 - val_precision: 0.7811 - val_recall: 0.3565 - val_auc: 0.8899 - val_f1_score: 0.4887
# Epoch 17/100
# 449/449 [==============================] - 55s 122ms/step - loss: 2.2381 - accuracy: 0.8911 - precision: 0.7152 - recall: 0.3955 - auc: 0.8822 - f1_score: 0.5084 - val_loss: 1.5958 - val_accuracy: 0.8812 - val_precision: 0.6733 - val_recall: 0.3272 - val_auc: 0.8479 - val_f1_score: 0.4366
# Epoch 18/100
# 449/449 [==============================] - 54s 120ms/step - loss: 2.1679 - accuracy: 0.8931 - precision: 0.7195 - recall: 0.4124 - auc: 0.8864 - f1_score: 0.5236 - val_loss: 1.3252 - val_accuracy: 0.8992 - val_precision: 0.7437 - val_recall: 0.4496 - val_auc: 0.9026 - val_f1_score: 0.5585
# Epoch 19/100
# 449/449 [==============================] - 55s 121ms/step - loss: 2.0937 - accuracy: 0.8948 - precision: 0.7230 - recall: 0.4268 - auc: 0.8932 - f1_score: 0.5360 - val_loss: 1.5725 - val_accuracy: 0.8812 - val_precision: 0.6521 - val_recall: 0.3614 - val_auc: 0.8522 - val_f1_score: 0.4626
# Epoch 20/100
# 449/449 [==============================] - 55s 122ms/step - loss: 2.0626 - accuracy: 0.8969 - precision: 0.7322 - recall: 0.4383 - auc: 0.8962 - f1_score: 0.5475 - val_loss: 1.3262 - val_accuracy: 0.8972 - val_precision: 0.7340 - val_recall: 0.4401 - val_auc: 0.8985 - val_f1_score: 0.5490
# Epoch 21/100
# 449/449 [==============================] - 55s 123ms/step - loss: 1.9815 - accuracy: 0.9001 - precision: 0.7400 - recall: 0.4639 - auc: 0.9035 - f1_score: 0.5696 - val_loss: 1.4297 - val_accuracy: 0.8882 - val_precision: 0.6704 - val_recall: 0.4270 - val_auc: 0.8793 - val_f1_score: 0.5198
# Epoch 22/100
# 449/449 [==============================] - 56s 125ms/step - loss: 1.9383 - accuracy: 0.9014 - precision: 0.7437 - recall: 0.4723 - auc: 0.9057 - f1_score: 0.5770 - val_loss: 1.3184 - val_accuracy: 0.8990 - val_precision: 0.7236 - val_recall: 0.4745 - val_auc: 0.8978 - val_f1_score: 0.5704
# Epoch 23/100
# 449/449 [==============================] - 55s 123ms/step - loss: 1.8542 - accuracy: 0.9041 - precision: 0.7492 - recall: 0.4945 - auc: 0.9127 - f1_score: 0.5951 - val_loss: 1.2865 - val_accuracy: 0.8968 - val_precision: 0.6935 - val_recall: 0.4975 - val_auc: 0.9033 - val_f1_score: 0.5771
# Epoch 24/100
# 449/449 [==============================] - 55s 123ms/step - loss: 1.8432 - accuracy: 0.9046 - precision: 0.7503 - recall: 0.4981 - auc: 0.9140 - f1_score: 0.5981 - val_loss: 1.2743 - val_accuracy: 0.9005 - val_precision: 0.7124 - val_recall: 0.5086 - val_auc: 0.9032 - val_f1_score: 0.5920
# Epoch 25/100
# 449/449 [==============================] - 55s 123ms/step - loss: 1.7835 - accuracy: 0.9075 - precision: 0.7549 - recall: 0.5214 - auc: 0.9188 - f1_score: 0.6161 - val_loss: 1.2903 - val_accuracy: 0.9001 - val_precision: 0.7346 - val_recall: 0.4705 - val_auc: 0.8973 - val_f1_score: 0.5724
# Epoch 26/100
# 449/449 [==============================] - 55s 122ms/step - loss: 1.7292 - accuracy: 0.9107 - precision: 0.7687 - recall: 0.5366 - auc: 0.9237 - f1_score: 0.6313 - val_loss: 1.4195 - val_accuracy: 0.8885 - val_precision: 0.6668 - val_recall: 0.4391 - val_auc: 0.8767 - val_f1_score: 0.5292
# Epoch 27/100
# 449/449 [==============================] - 54s 121ms/step - loss: 1.7020 - accuracy: 0.9107 - precision: 0.7618 - recall: 0.5451 - auc: 0.9241 - f1_score: 0.6349 - val_loss: 1.2690 - val_accuracy: 0.8987 - val_precision: 0.7038 - val_recall: 0.5022 - val_auc: 0.9018 - val_f1_score: 0.5865
# Epoch 28/100
# 449/449 [==============================] - 54s 121ms/step - loss: 1.6537 - accuracy: 0.9128 - precision: 0.7683 - recall: 0.5581 - auc: 0.9286 - f1_score: 0.6458 - val_loss: 1.2761 - val_accuracy: 0.8993 - val_precision: 0.6957 - val_recall: 0.5245 - val_auc: 0.9014 - val_f1_score: 0.5972
# Epoch 29/100
# 449/449 [==============================] - 53s 119ms/step - loss: 1.5724 - accuracy: 0.9175 - precision: 0.7818 - recall: 0.5857 - auc: 0.9350 - f1_score: 0.6690 - val_loss: 1.2440 - val_accuracy: 0.9004 - val_precision: 0.7048 - val_recall: 0.5215 - val_auc: 0.9050 - val_f1_score: 0.5986
# Epoch 30/100
# 449/449 [==============================] - 54s 119ms/step - loss: 1.5492 - accuracy: 0.9183 - precision: 0.7820 - recall: 0.5934 - auc: 0.9370 - f1_score: 0.6742 - val_loss: 1.1932 - val_accuracy: 0.9055 - val_precision: 0.7219 - val_recall: 0.5502 - val_auc: 0.9128 - val_f1_score: 0.6211
# Epoch 31/100
# 449/449 [==============================] - 54s 119ms/step - loss: 1.4742 - accuracy: 0.9216 - precision: 0.7906 - recall: 0.6134 - auc: 0.9416 - f1_score: 0.6903 - val_loss: 1.2583 - val_accuracy: 0.9010 - val_precision: 0.7087 - val_recall: 0.5217 - val_auc: 0.9019 - val_f1_score: 0.6001
# Epoch 32/100
# 449/449 [==============================] - 53s 118ms/step - loss: 1.4442 - accuracy: 0.9234 - precision: 0.7961 - recall: 0.6237 - auc: 0.9436 - f1_score: 0.6989 - val_loss: 1.2004 - val_accuracy: 0.9045 - val_precision: 0.7158 - val_recall: 0.5504 - val_auc: 0.9109 - val_f1_score: 0.6229
# Epoch 33/100
# 449/449 [==============================] - 54s 119ms/step - loss: 1.3853 - accuracy: 0.9261 - precision: 0.8018 - recall: 0.6413 - auc: 0.9480 - f1_score: 0.7120 - val_loss: 1.2265 - val_accuracy: 0.9030 - val_precision: 0.6995 - val_recall: 0.5630 - val_auc: 0.9093 - val_f1_score: 0.6243
# Epoch 34/100
# 449/449 [==============================] - 54s 120ms/step - loss: 1.3413 - accuracy: 0.9290 - precision: 0.8084 - recall: 0.6592 - auc: 0.9506 - f1_score: 0.7256 - val_loss: 1.2796 - val_accuracy: 0.9002 - val_precision: 0.6859 - val_recall: 0.5556 - val_auc: 0.9037 - val_f1_score: 0.6139
# Epoch 35/100
# 449/449 [==============================] - 55s 122ms/step - loss: 1.3372 - accuracy: 0.9291 - precision: 0.8089 - recall: 0.6595 - auc: 0.9518 - f1_score: 0.7263 - val_loss: 1.3692 - val_accuracy: 0.8982 - val_precision: 0.6742 - val_recall: 0.5559 - val_auc: 0.8926 - val_f1_score: 0.6090
# Epoch 36/100
# 449/449 [==============================] - 54s 120ms/step - loss: 1.2804 - accuracy: 0.9318 - precision: 0.8115 - recall: 0.6804 - auc: 0.9553 - f1_score: 0.7398 - val_loss: 1.2429 - val_accuracy: 0.9015 - val_precision: 0.6909 - val_recall: 0.5619 - val_auc: 0.9049 - val_f1_score: 0.6189
# Epoch 37/100
# 449/449 [==============================] - 53s 117ms/step - loss: 1.2403 - accuracy: 0.9346 - precision: 0.8197 - recall: 0.6954 - auc: 0.9575 - f1_score: 0.7520 - val_loss: 1.2848 - val_accuracy: 0.8984 - val_precision: 0.6798 - val_recall: 0.5465 - val_auc: 0.8995 - val_f1_score: 0.6049
# Epoch 38/100
# 449/449 [==============================] - 53s 118ms/step - loss: 1.1762 - accuracy: 0.9370 - precision: 0.8259 - recall: 0.7082 - auc: 0.9615 - f1_score: 0.7622 - val_loss: 1.3041 - val_accuracy: 0.8951 - val_precision: 0.6615 - val_recall: 0.5439 - val_auc: 0.8990 - val_f1_score: 0.5979
# Epoch 39/100
# 449/449 [==============================] - 54s 120ms/step - loss: 1.1280 - accuracy: 0.9401 - precision: 0.8344 - recall: 0.7248 - auc: 0.9644 - f1_score: 0.7754 - val_loss: 1.3381 - val_accuracy: 0.8965 - val_precision: 0.6656 - val_recall: 0.5541 - val_auc: 0.8958 - val_f1_score: 0.6045
# Epoch 40/100
# 449/449 [==============================] - 54s 120ms/step - loss: 1.1608 - accuracy: 0.9388 - precision: 0.8312 - recall: 0.7176 - auc: 0.9628 - f1_score: 0.7697 - val_loss: 1.2697 - val_accuracy: 0.9013 - val_precision: 0.6809 - val_recall: 0.5814 - val_auc: 0.9056 - val_f1_score: 0.6265
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 41/100
# 449/449 [==============================] - 53s 118ms/step - loss: 0.9418 - accuracy: 0.9517 - precision: 0.8681 - recall: 0.7807 - auc: 0.9755 - f1_score: 0.8218 - val_loss: 1.2638 - val_accuracy: 0.9026 - val_precision: 0.6819 - val_recall: 0.5960 - val_auc: 0.9092 - val_f1_score: 0.6345
# Epoch 42/100
# 449/449 [==============================] - 54s 119ms/step - loss: 0.8787 - accuracy: 0.9549 - precision: 0.8734 - recall: 0.8004 - auc: 0.9781 - f1_score: 0.8351 - val_loss: 1.3140 - val_accuracy: 0.9016 - val_precision: 0.6760 - val_recall: 0.5984 - val_auc: 0.9046 - val_f1_score: 0.6349
# Epoch 43/100
# 449/449 [==============================] - 54s 121ms/step - loss: 0.8325 - accuracy: 0.9575 - precision: 0.8794 - recall: 0.8144 - auc: 0.9799 - f1_score: 0.8455 - val_loss: 1.3051 - val_accuracy: 0.9022 - val_precision: 0.6759 - val_recall: 0.6064 - val_auc: 0.9071 - val_f1_score: 0.6390
# Epoch 44/100
# 449/449 [==============================] - 54s 121ms/step - loss: 0.8046 - accuracy: 0.9589 - precision: 0.8833 - recall: 0.8204 - auc: 0.9814 - f1_score: 0.8505 - val_loss: 1.3080 - val_accuracy: 0.9019 - val_precision: 0.6756 - val_recall: 0.6032 - val_auc: 0.9069 - val_f1_score: 0.6358
# Epoch 45/100
# 449/449 [==============================] - 55s 122ms/step - loss: 0.7950 - accuracy: 0.9599 - precision: 0.8854 - recall: 0.8259 - auc: 0.9817 - f1_score: 0.8544 - val_loss: 1.3279 - val_accuracy: 0.9033 - val_precision: 0.6755 - val_recall: 0.6215 - val_auc: 0.9077 - val_f1_score: 0.6455
# Epoch 46/100
# 449/449 [==============================] - 55s 121ms/step - loss: 0.7472 - accuracy: 0.9625 - precision: 0.8923 - recall: 0.8386 - auc: 0.9839 - f1_score: 0.8644 - val_loss: 1.3751 - val_accuracy: 0.8995 - val_precision: 0.6633 - val_recall: 0.6017 - val_auc: 0.9016 - val_f1_score: 0.6310
# Epoch 47/100
# 449/449 [==============================] - 54s 120ms/step - loss: 0.7222 - accuracy: 0.9631 - precision: 0.8913 - recall: 0.8444 - auc: 0.9842 - f1_score: 0.8670 - val_loss: 1.3796 - val_accuracy: 0.9003 - val_precision: 0.6648 - val_recall: 0.6096 - val_auc: 0.9022 - val_f1_score: 0.6370
# Epoch 48/100
# 449/449 [==============================] - 54s 120ms/step - loss: 0.7062 - accuracy: 0.9641 - precision: 0.8956 - recall: 0.8473 - auc: 0.9854 - f1_score: 0.8707 - val_loss: 1.3699 - val_accuracy: 0.9042 - val_precision: 0.6784 - val_recall: 0.6258 - val_auc: 0.9056 - val_f1_score: 0.6507
# Epoch 49/100
# 449/449 [==============================] - 54s 120ms/step - loss: 0.6803 - accuracy: 0.9658 - precision: 0.9006 - recall: 0.8551 - auc: 0.9863 - f1_score: 0.8771 - val_loss: 1.3739 - val_accuracy: 0.9026 - val_precision: 0.6685 - val_recall: 0.6308 - val_auc: 0.9063 - val_f1_score: 0.6487
# Epoch 50/100
# 449/449 [==============================] - 54s 121ms/step - loss: 0.6431 - accuracy: 0.9677 - precision: 0.9047 - recall: 0.8651 - auc: 0.9873 - f1_score: 0.8843 - val_loss: 1.3993 - val_accuracy: 0.9010 - val_precision: 0.6636 - val_recall: 0.6222 - val_auc: 0.9044 - val_f1_score: 0.6404
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 00050: early stopping

# %% [markdown]
# # 6. Evaluate Model

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 449/449 [==============================] - 46s 103ms/step - loss: 0.4088 - accuracy: 0.9700 - precision: 0.9091 - recall: 0.8780 - auc: 0.9910 - f1_score: 0.8933
# 113/113 [==============================] - 6s 53ms/step - loss: 1.3993 - accuracy: 0.9010 - precision: 0.6636 - recall: 0.6222 - auc: 0.9044 - f1_score: 0.6412

# %%
metric_list = ["Loss","Accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>0.409</td>
#       <td>1.399</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.970</td>
#       <td>0.901</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.909</td>
#       <td>0.664</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.878</td>
#       <td>0.622</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.991</td>
#       <td>0.904</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.893</td>
#       <td>0.641</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6.2 Visualize results

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %% [markdown]
# ## 6.3 Confusion Matrix

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[148  12  93 222 156 216 111]
#  [ 15   1  10  25  18  26  16]
#  [147  17  93 255 166 230 116]
#  [227  27 158 446 300 403 213]
#  [197  23 145 292 191 260 125]
#  [187  17 117 309 186 287 144]
#  [107  10  74 200 140 196 104]]

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()

# %% [markdown]
# # 7. Save Model

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # 8. Test/Predict

# %%
plt.style.use('grayscale')
plt.grid(visible=None)
img_path='../input/fer2013/test/happy/PrivateTest_3333329.jpg'
test_image=image.load_img(img_path,target_size= IMAGE_SIZE,color_mode='grayscale')
test_image=image.img_to_array(test_image)
print(test_image.shape)
plt.imshow(test_image)
plt.show()
# Out:
# (48, 48, 1)

# %%
img=image.load_img(img_path,target_size=IMAGE_SIZE)
img = np.expand_dims(img, axis=0)
print(img.shape)
# Out:
# (1, 48, 48, 3)

# %%
result=model.predict(img)
print(result[0])
y_pred=np.argmax(result[0])
print('The person facial emotion is:',classes[y_pred])
# Out:
# [0. 0. 0. 1. 0. 0. 0.]
# The person facial emotion is: Happy
